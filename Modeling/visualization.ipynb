# %% [markdown]
# <a href="https://colab.research.google.com/github/yukyeongmin/NenepBigData/blob/master/Modeling/GloVeLSTMsimple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#구글 드라이브와 코랩 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import copy
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm

SEED = 123
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchtext import data, datasets
from torchtext.vocab import GloVe
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedShuffleSplit
from gensim.models.word2vec import Word2Vec

# %%
dataset = pd.read_csv("/content/drive/MyDrive/lemmatizing.csv",index_col = 0)
dataset.head()
# Out:
#                                               review  label
# 0  act end atmosphere despair mixed happy moment ...      3
# 1  honest go watch film negative mind anyway hear...      7
# 2  year gibson braveheart scottish movie false ex...      8
# 3  change story dad really thing movie go decent ...      1
# 4  movie potential top line intelligent science f...      7

# %%
dataset.groupby('label').size().plot(kind='bar', color='g')

# %% [markdown]
# # **Split Train and Test data**

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size = 0.3, random_state=77)
for train_idx, test_idx in split.split(dataset, dataset["label"]):
  trainset = dataset.loc[train_idx]
  testset = dataset.loc[test_idx]

# %%
trainset = trainset.reset_index(drop = True)
testset = testset.reset_index(drop = True)

trainset.to_csv("/content/drive/MyDrive/trainset.csv",index = False)
testset.to_csv("/content/drive/MyDrive/testset.csv", index = False)

# %%
TEXT = data.Field(sequential = True,
                  use_vocab = True,
                  tokenize = "spacy",
                  batch_first = True)
LABEL = data.Field(sequential = False,
                   use_vocab = False,
                   batch_first = False,
                   is_target = True)
fields = [('review', TEXT),('label',LABEL)]
train_data, test_data = data.TabularDataset.splits(path = "/content/drive/MyDrive/",
                                     train = 'trainset.csv',
                                     test = 'testset.csv', 
                                     format = "csv", fields = fields,
                                     skip_header = True)

# %%
print(vars(train_data[0]))
# Out:
# {'review': ['keep', 'hop', 'wake', 'see', 'one', 'top', 'three', 'movie', 'time', 'dream', 'dupe', 'payola', 'ridden', 'viral', 'fest', 'rating', 'entertainment', 'net', 'become', 'example', 'intelligent', 'comic', 'book', 'treatment', 'film', 'example', 'intelligent', 'film', 'dream', 'neither', 'currently', 'rat', 'mile', 'shill', 'figure', 'conceptual', 'shortcoming', 'good', 'movie', 'technical', 'perspective', 'overact', 'entire', 'cast', 'effort', 'bring', 'life', 'snooze', 'even', 'high', 'dollar', 'action', 'scene', 'cgi', 'liven', 'comic', 'relief', 'none', 'whatsoever', 'allay', 'squirm', 'theater', 'seat', 'wonder', 'ever', 'love', 'interest', 'subplot', 'head', 'scratchingly', 'extraneous', 'might', 'interest', 'corporate', 'espionage', 'thriller', 'carry', 'movie', 'save', 'life', 'fact', 'entire', 'cast', 'miscast', 'disagree', 'dream', 'cast', 'lead', 'tell', 'wrong'], 'label': '7'}

# %% [markdown]
# # **Use Pre-trained GloVe word embedding**

# %%
TEXT.build_vocab(train_data, vectors = GloVe(name = '6B',dim = 300),
                 max_size = 50000, min_freq = 4)
LABEL.build_vocab(train_data)
# Out:
# .vector_cache/glove.6B.zip: 862MB [06:28, 2.22MB/s]
# 100%|█████████▉| 399182/400000 [00:41<00:00, 9556.53it/s]

# %%
vocab_size = len(TEXT.vocab)
n_classes = 9
print("단어 집합의 크기 : {}".format(vocab_size))
print("클래스의 개수 : {}".format(n_classes))
# Out:
# 단어 집합의 크기 : 25039
# 클래스의 개수 : 9

# %%
print("임베딩 벡터의 개수와 차원 : {}".format(TEXT.vocab.vectors.shape))
# Out:
# 임베딩 벡터의 개수와 차원 : torch.Size([25039, 300])

# %%
#print(TEXT.vocab.stoi)
a=TEXT.vocab.freqs.most_common(50)
index=list()
value=list()
for i in a:
  index.append(i[0])
  value.append(i[1])
fig = plt.figure(figsize=(12, 12))
plt.barh(index, value, color='y')
plt.xticks(rotation=45)
# Out:
# (array([     0.,  50000., 100000., 150000., 200000., 250000.]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# # **Split Train and Val Data**

# %%
trainset, valset = train_data.split(split_ratio=0.8)
ratio=[len(trainset),len(valset), len(test_data)]
labels=['train', 'validation','test']
explode = [0.05, 0.05, 0.05]
plt.pie(ratio, labels=labels,autopct='%0.1f%%', colors=["gray", "gray", "red"], explode=explode )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4253952080>,
#   <matplotlib.patches.Wedge at 0x7f425389b3c8>,
#   <matplotlib.patches.Wedge at 0x7f425389ba20>],
#  [Text(-0.21548852023467327, 1.1296303367239529, 'train'),
#   Text(-0.7872291576900415, -0.8383139348016517, 'validation'),
#   Text(0.6759530924008326, -0.9303695055588138, 'test')],
#  [Text(-0.12179785926307618, 0.6384867120613645, '56.0%'),
#   Text(-0.4449556108682843, -0.47382961532267265, '14.0%'),
#   Text(0.3820604435309054, -0.5258610248810686, '30.0%')])

# %%
train_iter, val_iter, test_iter = data.BucketIterator.splits((trainset,valset,test_data), batch_size = 64, shuffle = True, sort = False)

# %%
print('훈련 데이터의 미니 배치의 개수 : {}'.format(len(train_iter)))
print('테스트 데이터의 미니 배치의 개수 : {}'.format(len(test_iter)))
print('검증 데이터의 미니 배치의 개수 : {}'.format(len(val_iter)))
# Out:
# 훈련 데이터의 미니 배치의 개수 : 1284
# 테스트 데이터의 미니 배치의 개수 : 688
# 검증 데이터의 미니 배치의 개수 : 321

# %%
# batch = next(iter(test_iter))
# batch

# %%
# batch = next(iter(val_iter))
# batch

# %%
# batch = next(iter(train_iter))
# batch

# %%
is_cuda = torch.cuda.is_available()
print("Cuda Status on system is {}".format(is_cuda))
# Out:
# Cuda Status on system is True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # **Construct Stacked LSTM(2Layer)**

# %%
#RNN 모델
class RNN(nn.Module):
  def __init__(self, embedding_vectors, embedding_size, hidden_size):
    super().__init__()
    self.embedding_vectors = embedding_vectors
    self.embedding_size = embedding_size
    self.hidden_size = hidden_size

    self.embedding_layer = nn.Embedding.from_pretrained(embedding_vectors,freeze = False)
    # LSTM Layer
    self.LSTM = nn.Sequential(
        nn.LSTM(
        input_size = embedding_size,
        hidden_size = hidden_size,
        num_layers = 2,                       # stacked LSTM 2layers
        batch_first = True),
    )
    # fully-connected Layer
    self.fc1 = nn.Sequential(
        nn.Linear(hidden_size, hidden_size),
        nn.ReLU()
    )
    self.fc2 = nn.Sequential(
        nn.Linear(hidden_size, 9)
    )
    
  def forward(self, x):
    y = self.embedding_layer(x)
    weight = self._init_state(batch_size = x.size(0))
    y, hidden = self.LSTM(y)
    h_t = y[:,-1,:]
    y = self.fc1(h_t)
    y = self.fc2(y)
    return y

  def _init_state(self, batch_size=1):
    weight = next(self.parameters()).data
    return weight.new(batch_size, self.hidden_size).zero_()

# %% [markdown]
# # **Training sequence(epoch = 10, LR = 0.003, min_freq = 4)**

# %%
epoch = 10
learning_rate = 0.003
# LSTM using Pytorch
def LSTM_Train(train_loader, test_loader, epoch, learning_rate, no_cuda = False):
  use_cuda = not no_cuda and torch.cuda.is_available()
  device = torch.device("cuda" if use_cuda else "cpu")
  Model = RNN(TEXT.vocab.vectors,300,300).to(device)
  optimizer = torch.optim.AdamW(Model.parameters(), lr = learning_rate)
  train_L_iters = []
  train_acc_iters = []
  test_L_iters = []
  test_acc_iters = []
  best_test_loss = 100000
  for i in range(1,epoch+1):
    # Train mode
    train_loss = 0
    train_correct = 0
    Model.train()
    for batch_idx, batch in enumerate(train_loader):
      # data와 target을 gpu를 사용할 수 있게 매핑
      data, target = batch.review.to(device), batch.label.to(device)
      # backward하는 과정에서 기존의 gradient값에 새로운 gradient 값을
      # 더해주기때문에 grad값을 매 backward마다 0으로 초기화해줘야 올바른 학습이 가능
      optimizer.zero_grad()
      # 순전파
      output = Model(data)
      # reduction = (default) "mean"
      loss = F.cross_entropy(output,target)
      train_loss += F.cross_entropy(output,target,reduction = 'sum').item()
      pred = output.argmax(dim = 1, keepdim = True)
      train_correct += pred.eq(target.view_as(pred)).sum().item()
      # 역전파
      loss.backward()
      optimizer.step()
    # 에포크별 평균 트레인 로스 계산
    train_loss /= len(train_loader.dataset)
    train_L_iters.append(train_loss)
    # 에포크별 평균 정확도 계산
    accuracy =  100 * train_correct / len(train_loader.dataset)
    train_acc_iters.append(accuracy)    
    # torch.no_grad() 테스트 할 때, 위에서 계산한 grad를 더이상 업데이트 하지 않음.
    with torch.no_grad():
      Model.eval()
      test_loss = 0
      test_correct = 0
      for batch in test_loader:
        data, target = batch.review.to(device), batch.label.to(device)
        output = Model(data)
        test_loss += F.cross_entropy(output, target, reduction = 'sum').item()
        pred = output.argmax(dim = 1, keepdim = True)
        test_correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_L_iters.append(test_loss)
    accuracy = 100 * test_correct / len(test_loader.dataset)
    test_acc_iters.append(accuracy)
    if i % 1 == 0:
      print("progress = {}, current loss = {}, current device = {}".format(100 * i / epoch, train_loss, torch.cuda.get_device_name()))
      print("test loss = {} test accuracy = {}\n".format(test_loss, accuracy))
    if not best_test_loss or test_loss < best_test_loss:
      torch.save(Model.state_dict(),"/content/drive/MyDrive/genreclassification.pt")
      best_test_loss = test_loss
  return train_L_iters, train_acc_iters, test_L_iters, test_acc_iters

# %%
train_L_iters, train_acc_iters, test_L_iters, test_acc_iters = LSTM_Train(train_iter,val_iter, epoch, learning_rate)
# Out:
# progress = 10.0, current loss = 2.111662759092723, current device = Tesla T4
# test loss = 2.1063685048020027 test accuracy = 17.708637647287954
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0ca6cab0353f> in <module>()
# ----> 1 train_L_iters, train_acc_iters, test_L_iters, test_acc_iters = LSTM_Train(train_iter,val_iter, epoch, learning_rate)
#
# <ipython-input-23-e78dd6cd1348> in LSTM_Train(train_loader, test_loader, epoch, learning_rate, no_cuda)
#      27       # reduction = (default) "mean"
#      28       loss = F.cross_entropy(output,target)
# ---> 29       train_loss += F.cross_entropy(output,target,reduction = 'sum').item()
#      30       pred = output.argmax(dim = 1, keepdim = True)
#      31       train_correct += pred.eq(target.view_as(pred)).sum().item()
#
# KeyboardInterrupt:

# %% [markdown]
# # **Plot the loss curve**

# %%
plt.figure(figsize = (7,7))
plt.plot(train_L_iters, c = "red", label = "train loss")
plt.plot(test_L_iters, c = "blue", label = "val loss")
plt.title("loss at batch_size = 64")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **Plot the Accuracy curve**

# %%
plt.figure(figsize = (7,7))
plt.plot(train_acc_iters, c = "red", label = "train accuracy")
plt.plot(test_acc_iters, c = "blue", label = "val accuracy")
plt.title("accuracy at batch_size = 64")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **Model Test**

# %%
model = RNN(TEXT.vocab.vectors,300,300).to(device)
model.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/bigdata/genreclassification.pt'))
model.eval()
tot_loss = 0
tot_correct = 0
for batch in test_iter:
  data, target = batch.review.to(device), batch.label.to(device)
  output = model(data)
  tot_loss += F.cross_entropy(output, target, reduction = 'sum').item()
  pred = output.argmax(dim = 1, keepdim = True)
  tot_correct += pred.eq(target.view_as(pred)).sum().item()
tot_loss /= len(test_iter.dataset)
accuracy = 100 * tot_correct / len(test_iter.dataset)
print("테스트 오차 : %5.2f | 테스트 정확도 : %5.2f" % (tot_loss,accuracy))
# Out:
# 테스트 오차 :  0.89 | 테스트 정확도 : 69.96

# %% [markdown]
# # **MultiLabel Confusion Matrix**

# %% [markdown]
# # **Word Cloud**

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud) (1.18.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud) (7.0.0)

# %%
from wordcloud import WordCloud

moviegenres = ["ActionAdventure", "Animation", "Biography", "Crime Action", "Horror", "Mytery Thriller", "Romantic Comedy", "Sci - Fi", "War"]

for i in range(9):
  labeldic = {}
  labelfile = "/content/drive/MyDrive/LabelTopWords/label " + str(i) + ".csv"
  label = pd.read_csv(labelfile,index_col = 0)
  print(labelfile)
  for j in range(len(label)):
    if((label.loc[j][0] != 'movie') and (label.loc[j][0] != 'film')):
      labeldic[label.loc[j][0]] = int(label.loc[j][1])

  print(labeldic)
  wordCloud = WordCloud(background_color = "white", width=1600, height = 800).generate_from_frequencies(labeldic)
  plt.figure(figsize = (16,8), facecolor='w')
  plt.title(moviegenres[i], fontsize = 50)
  plt.imshow(wordCloud)
# Out:
# /content/drive/MyDrive/LabelTopWords/label 0.csv
# {'one': 14940, 'make': 14717, 'like': 14296, 'see': 14251, 'time': 13080, 'good': 12190, 'character': 11838, 'story': 11501, 'scene': 10778, 'get': 10423, 'well': 10061, 'great': 9862, 'really': 8284, 'watch': 8129, 'think': 7661, 'much': 7660, 'say': 6951, 'end': 6531, 'action': 6508, 'even': 6490, 'take': 6377, 'give': 6300, 'way': 6213, 'go': 6006, 'know': 5897, 'look': 5896, 'also': 5628, 'people': 5584, 'love': 5501, 'best': 5416, 'act': 5293, 'many': 5227, 'first': 5204, 'come': 5145, 'thing': 5005, 'long': 4881, 'effect': 4681, 'actor': 4523, 'hour': 4498, 'bad': 4497, 'feel': 4486, 'year': 4282, 'want': 4147, 'show': 4116, 'find': 4046, 'performance': 4016, 'seem': 4015, 'part': 3890, 'play': 3877, 'work': 3870, 'never': 3835, 'plot': 3775, 'fight': 3769, 'still': 3746, 'back': 3738, 'ever': 3573, 'big': 3557, 'little': 3500, 'battle': 3480, 'lot': 3438, 'man': 3387, 'life': 3312, 'role': 3296, 'original': 3170, 'use': 3166, 'cast': 3129, 'director': 3053, 'real': 3030, 'set': 3001, 'two': 2989, 'epic': 2947, 'every': 2875, 'special': 2831, 'point': 2800, 'though': 2788, 'leave': 2785, 'try': 2779, 'tell': 2779, 'something': 2748, 'do': 2731, 'kill': 2693, 'minute': 2677, 'need': 2641, 'start': 2587, 'bit': 2560, 'screen': 2513, 'moment': 2402, 'world': 2367, 'another': 2336, 'last': 2331, 'new': 2327, 'old': 2310, 'nothing': 2300, 'enjoy': 2272, 'quite': 2266, 'far': 2242, 'enough': 2239, 'audience': 2235}
# /content/drive/MyDrive/LabelTopWords/label 1.csv
# {'like': 8918, 'character': 7933, 'story': 7648, 'one': 7478, 'make': 7405, 'see': 6806, 'good': 5974, 'animation': 5600, 'watch': 5428, 'love': 5303, 'great': 5291, 'really': 4923, 'time': 4900, 'well': 4889, 'get': 4683, 'original': 4606, 'song': 4554, 'think': 3880, 'much': 3583, 'voice': 3498, 'even': 3397, 'also': 3375, 'look': 3321, 'say': 3272, 'best': 3179, 'way': 2977, 'feel': 2956, 'give': 2955, 'take': 2937, 'scene': 2895, 'family': 2863, 'go': 2861, 'thing': 2831, 'come': 2817, 'year': 2752, 'know': 2674, 'music': 2662, 'people': 2592, 'new': 2522, 'animate': 2521, 'kid': 2449, 'end': 2343, 'first': 2298, 'many': 2277, 'find': 2262, 'little': 2251, 'want': 2209, 'still': 2200, 'child': 2109, 'life': 2070, 'work': 1964, 'show': 1959, 'lot': 1903, 'plot': 1899, 'bad': 1898, 'old': 1886, 'version': 1811, 'something': 1802, 'ever': 1779, 'classic': 1764, 'remake': 1760, 'beautiful': 1758, 'never': 1739, 'heart': 1722, 'emotion': 1697, 'live': 1691, 'real': 1648, 'every': 1640, 'enjoy': 1640, 'part': 1625, 'world': 1614, 'action': 1565, 'fun': 1557, 'seem': 1549, 'back': 1514, 'funny': 1501, 'try': 1492, 'need': 1485, 'young': 1453, 'act': 1450, 'tell': 1414, 'felt': 1391, 'two': 1379, 'do': 1363, 'use': 1348, 'different': 1333, 'moment': 1325, 'big': 1319, 'animal': 1309, 'musical': 1309, 'though': 1308, 'bring': 1283, 'point': 1263, 'bit': 1254, 'book': 1242, 'start': 1220, 'review': 1204, 'comic': 1170}
# /content/drive/MyDrive/LabelTopWords/label 2.csv
# {'make': 11410, 'one': 11390, 'like': 9867, 'see': 9740, 'story': 9432, 'time': 8998, 'great': 8280, 'watch': 7816, 'good': 7546, 'character': 7213, 'get': 6945, 'well': 6718, 'scene': 6250, 'best': 5857, 'really': 5616, 'people': 5314, 'life': 5251, 'think': 4866, 'performance': 4771, 'say': 4642, 'much': 4520, 'even': 4486, 'way': 4436, 'give': 4419, 'act': 4344, 'show': 4340, 'know': 4301, 'also': 4204, 'actor': 4086, 'take': 4075, 'love': 3950, 'end': 3839, 'feel': 3809, 'many': 3648, 'work': 3626, 'play': 3619, 'go': 3616, 'year': 3563, 'come': 3317, 'long': 3299, 'ever': 3298, 'thing': 3191, 'look': 3155, 'never': 3121, 'hour': 3104, 'man': 3060, 'want': 3054, 'real': 2968, 'first': 2901, 'tell': 2888, 'cast': 2729, 'every': 2606, 'TRUE': 2547, 'still': 2496, 'two': 2461, 'role': 2438, 'use': 2371, 'part': 2286, 'find': 2260, 'lot': 2234, 'musical': 2187, 'old': 2183, 'bad': 2152, 'seem': 2148, 'music': 2050, 'little': 2033, 'something': 2011, 'start': 2009, 'history': 1966, 'director': 1962, 'point': 1955, 'world': 1942, 'big': 1931, 'race': 1853, 'need': 1808, 'write': 1788, 'gangster': 1777, 'become': 1776, 'back': 1751, 'try': 1728, 'fact': 1728, 'guy': 1722, 'enjoy': 1720, 'do': 1706, 'car': 1702, 'money': 1692, 'song': 1691, 'always': 1655, 'moment': 1645, 'right': 1600, 'live': 1599, 'job': 1594, 'though': 1591, 'base': 1586, 'audience': 1566, 'minute': 1543, 'put': 1537, 'another': 1536}
# /content/drive/MyDrive/LabelTopWords/label 3.csv
# {'one': 19800, 'see': 17976, 'make': 17922, 'character': 17234, 'like': 16273, 'good': 14956, 'time': 13556, 'great': 12451, 'get': 12097, 'well': 11375, 'story': 10961, 'best': 10941, 'watch': 10762, 'performance': 10462, 'think': 10150, 'end': 9844, 'really': 9769, 'say': 9250, 'scene': 8997, 'give': 8167, 'people': 7995, 'act': 7985, 'much': 7935, 'way': 7826, 'even': 7668, 'go': 7465, 'know': 7456, 'take': 6830, 'also': 6395, 'ever': 6245, 'actor': 6099, 'come': 6049, 'play': 5965, 'thing': 5924, 'feel': 5700, 'bad': 5543, 'first': 5350, 'many': 5342, 'plot': 5255, 'action': 5239, 'role': 5214, 'work': 5199, 'never': 5097, 'want': 5093, 'show': 4851, 'two': 4737, 'find': 4703, 'love': 4693, 'look': 4663, 'life': 4606, 'year': 4550, 'dark': 4436, 'every': 4291, 'seem': 4281, 'man': 4075, 'killer': 4006, 'still': 4001, 'real': 3836, 'comic': 3757, 'cast': 3721, 'something': 3721, 'lot': 3715, 'long': 3637, 'try': 3612, 'part': 3587, 'book': 3553, 'crime': 3501, 'leave': 3480, 'point': 3473, 'world': 3396, 'guy': 3377, 'little': 3346, 'kill': 3303, 'joker': 3272, 'need': 3193, 'become': 3180, 'start': 3136, 'keep': 3090, 'perfect': 3069, 'write': 3057, 'use': 3053, 'villain': 3047, 'screen': 3037, 'tell': 2978, 'director': 2910, 'happen': 2882, 'big': 2881, 'another': 2866, 'always': 2850, 'thriller': 2845, 'back': 2832, 'nothing': 2828, 'turn': 2797, 'job': 2781, 'though': 2777, 'top': 2726, 'do': 2717, 'whole': 2650}
# /content/drive/MyDrive/LabelTopWords/label 4.csv
# {'show': 12688, 'season': 6324, 'like': 5750, 'watch': 5673, 'character': 5436, 'good': 4783, 'one': 4744, 'get': 4421, 'make': 4341, 'series': 4291, 'episode': 4131, 'story': 4003, 'see': 3926, 'really': 3560, 'well': 3344, 'time': 3314, 'love': 3294, 'great': 3231, 'first': 2681, 'end': 2644, 'think': 2616, 'much': 2430, 'horror': 2379, 'go': 2358, 'thing': 2337, 'say': 2298, 'know': 2215, 'act': 2204, 'even': 2167, 'give': 2118, 'bad': 2086, 'way': 2068, 'people': 1970, 'come': 1934, 'start': 1870, 'actor': 1789, 'plot': 1746, 'best': 1734, 'take': 1721, 'also': 1640, 'many': 1619, 'every': 1618, 'want': 1610, 'find': 1555, 'look': 1548, 'write': 1512, 'two': 1506, 'feel': 1485, 'work': 1376, 'never': 1366, 'scene': 1343, 'something': 1336, 'still': 1300, 'fan': 1290, 'lot': 1290, 'keep': 1279, 'back': 1263, 'year': 1234, 'play': 1233, 'personality': 1225, 'new': 1221, 'brother': 1217, 'try': 1209, 'seem': 1199, 'cast': 1166, 'different': 1147, 'girl': 1103, 'ever': 1095, 'little': 1063, 'part': 1052, 'enjoy': 1028, 'life': 1002, 'need': 999, 'main': 959, 'always': 954, 'review': 939, 'happen': 934, 'last': 910, 'another': 908, 'far': 905, 'supernatural': 903, 'performance': 903, 'dark': 897, 'become': 888, 'point': 888, 'use': 875, 'everything': 874, 'line': 873, 'wait': 872, 'next': 851, 'bit': 850, 'writer': 848, 'kill': 841, 'nothing': 837, 'monster': 835, 'hope': 833, 'actually': 828, 'turn': 823}
# /content/drive/MyDrive/LabelTopWords/label 5.csv
# {'one': 16503, 'see': 16385, 'make': 16018, 'like': 15629, 'end': 13828, 'time': 13357, 'good': 12769, 'watch': 12549, 'get': 12210, 'story': 11807, 'think': 10805, 'character': 10721, 'really': 10409, 'well': 10184, 'horror': 10009, 'great': 9213, 'go': 8544, 'plot': 8380, 'say': 8262, 'scene': 7903, 'know': 7853, 'way': 7784, 'act': 7389, 'people': 7291, 'much': 7278, 'even': 7275, 'give': 7241, 'thing': 6709, 'take': 6135, 'first': 5983, 'come': 5868, 'also': 5799, 'feel': 5636, 'twist': 5549, 'best': 5450, 'find': 5317, 'many': 5237, 'want': 5161, 'bad': 5074, 'work': 4827, 'look': 4755, 'performance': 4663, 'something': 4637, 'play': 4449, 'seem': 4353, 'start': 4324, 'love': 4314, 'never': 4222, 'leave': 4211, 'happen': 4198, 'try': 4144, 'two': 4048, 'keep': 4015, 'tell': 3990, 'director': 3741, 'point': 3709, 'lot': 3687, 'show': 3681, 'ever': 3678, 'thriller': 3661, 'still': 3660, 'part': 3617, 'wife': 3612, 'audience': 3572, 'actor': 3518, 'life': 3471, 'man': 3447, 'long': 3441, 'begin': 3435, 'little': 3416, 'year': 3401, 'write': 3395, 'family': 3385, 'use': 3335, 'turn': 3323, 'cast': 3309, 'review': 3249, 'mystery': 3203, 'every': 3165, 'minute': 3151, 'hour': 3010, 'whole': 2989, 'mind': 2975, 'real': 2967, 'sense': 2931, 'back': 2912, 'actually': 2882, 'last': 2748, 'nothing': 2712, 'need': 2678, 'moment': 2659, 'though': 2637, 'enjoy': 2619, 'bit': 2600, 'believe': 2595, 'everything': 2592, 'viewer': 2584, 'do': 2583}
# /content/drive/MyDrive/LabelTopWords/label 6.csv
# {'show': 3614, 'like': 2786, 'character': 2753, 'family': 2680, 'watch': 2436, 'one': 2345, 'make': 2210, 'good': 2030, 'see': 2028, 'love': 1967, 'get': 1833, 'story': 1675, 'time': 1636, 'really': 1521, 'well': 1409, 'think': 1325, 'people': 1295, 'great': 1158, 'much': 1113, 'end': 1102, 'funny': 1073, 'way': 1049, 'even': 1041, 'say': 1041, 'go': 1014, 'comedy': 1003, 'life': 978, 'know': 974, 'give': 948, 'season': 936, 'cast': 930, 'feel': 920, 'want': 919, 'episode': 912, 'thing': 912, 'series': 888, 'first': 877, 'scene': 865, 'bad': 861, 'come': 859, 'act': 852, 'many': 832, 'look': 831, 'also': 793, 'actor': 788, 'every': 743, 'play': 730, 'find': 724, 'plot': 699, 'year': 693, 'laugh': 684, 'try': 684, 'take': 667, 'seem': 657, 'write': 641, 'lot': 633, 'best': 622, 'enjoy': 603, 'never': 599, 'real': 583, 'work': 583, 'something': 575, 'rich': 573, 'mother': 554, 'little': 541, 'need': 530, 'moment': 511, 'part': 506, 'two': 496, 'start': 483, 'fun': 481, 'review': 478, 'still': 461, 'romantic': 459, 'new': 455, 'enough': 448, 'woman': 447, 'line': 444, 'bit': 443, 'ever': 442, 'expect': 433, 'day': 432, 'point': 431, 'girl': 430, 'nothing': 430, 'drama': 428, 'old': 419, 'whole': 416, 'tell': 416, 'another': 408, 'back': 406, 'mean': 403, 'live': 402, 'role': 400, 'actually': 396, 'different': 394, 'leave': 393, 'couple': 386}
# /content/drive/MyDrive/LabelTopWords/label 7.csv
# {'time': 21979, 'one': 21056, 'make': 19462, 'like': 19172, 'see': 18715, 'character': 15058, 'good': 13646, 'story': 13628, 'watch': 13582, 'get': 13501, 'action': 13325, 'great': 12211, 'think': 11709, 'well': 11692, 'really': 11128, 'scene': 9788, 'say': 9585, 'plot': 9173, 'best': 9006, 'much': 8922, 'even': 8604, 'go': 8502, 'end': 8347, 'effect': 8239, 'dream': 8062, 'way': 7937, 'know': 7871, 'first': 7625, 'give': 7595, 'world': 7333, 'thing': 7300, 'also': 7194, 'people': 7186, 'take': 7118, 'love': 6756, 'come': 6660, 'many': 6426, 'year': 6103, 'feel': 6085, 'look': 6073, 'back': 5892, 'act': 5766, 'work': 5658, 'mind': 5467, 'ever': 5442, 'want': 5426, 'idea': 5384, 'still': 5148, 'find': 5102, 'lot': 4892, 'never': 4867, 'bad': 4789, 'new': 4785, 'use': 4731, 'special': 4645, 'something': 4621, 'actor': 4374, 'try': 4373, 'understand': 4341, 'play': 4333, 'seem': 4305, 'real': 4271, 'part': 4257, 'future': 4233, 'need': 4203, 'space': 4174, 'big': 4094, 'every': 4041, 'little': 3954, 'original': 3942, 'leave': 3936, 'show': 3896, 'human': 3849, 'life': 3747, 'cast': 3730, 'two': 3642, 'point': 3624, 'start': 3621, 'science': 3565, 'long': 3514, 'sci': 3484, 'fan': 3482, 'tell': 3446, 'another': 3421, 'audience': 3346, 'whole': 3333, 'keep': 3307, 'performance': 3279, 'happen': 3278, 'director': 3208, 'everything': 3177, 'review': 3172, 'write': 3134, 'set': 3126, 'must': 3114, 'though': 3092, 'actually': 3083, 'star': 3075}
# /content/drive/MyDrive/LabelTopWords/label 8.csv
# {'war': 16068, 'one': 13501, 'make': 11489, 'see': 10850, 'like': 10660, 'scene': 9054, 'time': 8680, 'character': 8667, 'story': 8540, 'get': 7287, 'good': 7207, 'great': 6933, 'watch': 6664, 'well': 6406, 'soldier': 6088, 'really': 5793, 'think': 5357, 'say': 5261, 'best': 5190, 'way': 5116, 'much': 5006, 'take': 5004, 'end': 4866, 'give': 4648, 'even': 4639, 'feel': 4563, 'know': 4456, 'go': 4400, 'show': 4400, 'also': 4376, 'people': 4222, 'first': 4172, 'many': 4034, 'act': 3815, 'come': 3680, 'thing': 3441, 'work': 3355, 'ever': 3350, 'look': 3235, 'two': 3229, 'part': 3217, 'shot': 3117, 'never': 3085, 'find': 3025, 'love': 2970, 'action': 2964, 'performance': 2958, 'actor': 2941, 'real': 2925, 'want': 2897, 'tell': 2797, 'seem': 2697, 'play': 2690, 'life': 2679, 'year': 2677, 'use': 2619, 'kill': 2583, 'experience': 2582, 'point': 2580, 'director': 2566, 'bad': 2508, 'long': 2444, 'every': 2427, 'little': 2405, 'still': 2378, 'battle': 2305, 'moment': 2299, 'man': 2285, 'lot': 2255, 'try': 2206, 'plot': 2204, 'set': 2183, 'something': 2161, 'men': 2093, 'back': 2088, 'leave': 2071, 'start': 2031, 'cinematography': 2019, 'history': 1996, 'line': 1992, 'young': 1991, 'happen': 1946, 'fight': 1908, 'another': 1897, 'without': 1894, 'different': 1894, 'cast': 1854, 'big': 1836, 'audience': 1816, 'dialogue': 1816, 'almost': 1796, 'sound': 1791, 'felt': 1791, 'half': 1786, 'TRUE': 1780, 'screen': 1779, 'write': 1776, 'horror': 1768}
